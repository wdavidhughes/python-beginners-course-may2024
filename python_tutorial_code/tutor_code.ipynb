# %%
###################################################
# Tutor's code: Week 1
###################################################

# https://www.freecodecamp.org/news/tag/python/
# https://github.com/data-to-insight/ERN-sessions
# https://leetcode.com/

# In this cell, initialise two numeric variables and find their product 
# using the * operator for multiplication and assign this to a new variable.
# Print the new variable
j = 30
k = 0.5

i = j * k
print(i)

# The radius of a circle is 2, assume that Pi is 3.14. Assign both of these 
# to suitably named variables and find the area of the circle.
# We can find the area of a circle by finding the product of Pi with the radius squared.
# You probably don't know how to square a number in Python yet, so use Google to work it out!

# ** 2 (to square a number)

radius = 2
pi = 3.14

area = pi * (radius ** 2)

print(area)

# %%
################################################
# Week 2: tutors code
################################################
list_1 = []
print(type(list_1))

colours = ["red", "blue", "green"]
print(colours[-1])

colours.append("purple")
print(colours)

extra_colours = ["turquiose", "teal"]
colours.append(extra_colours)
print(colours)

colours.extend(extra_colours)
print(colours)

colours.extend("grey")
print(colours)

colours.extend(["purple", "purple", "purple"])
print(colours)

colours.remove("purple")
print(colours)

colours.remove("purple")
print(colours)
colours.remove("purple")
print(colours)
colours.remove("purple")
print(colours)

# Exercise 

# In this cell, make a list of a few foods and print it.
food = ["burger", "pizza", "chips"]
# Then append the list with another food and print it.
food.append("sausages")
# Next, make another list of foods, and use the extend method to 
# add those extra foods as individual elements of the list, and print it.
food.extend(["noodles", "pasty"])
# Finally, remove and element from the list and print the final list.
# Remember to always use a suitable name for your lists!
food.remove("pasty")

print(food)

# %%
# dict_1 = {key:value , key:value}
will = {"Name":"Will", 
        "Age":30, 
        "Pets":"1", 
        "Food":food,
        "Sport":"Running",
        "Colours":colours}
print(will)

print(will["Sport"])
print(will["Food"])

# Make a similar dictionary for yourself with keys such as name, food etc, print out some keys

# %%
# Dictionary
fav_cols = {"Will":"Purple",
            "Andy":["Purple", "Teal"],
            "Annie":{"Monday":"Red",
                     "Rest of the week":colours}
            }

print(fav_cols["Andy"][0])

print(fav_cols["Annie"]["Rest of the week"][-1])

print(fav_cols.keys())

print(fav_cols.values())

print(fav_cols.items())

fav_cols["Naiomi"] = "Yellow" # can extend dictionary directly if they don't exist
print(fav_cols)

fav_cols["Annie"] = "Gold" # can overwrite an existing value
print(fav_cols)

print("annie" in fav_cols)


# Make a dict of names and job titles, have about 3 entries
# Make sure one person has multiple jobs using a dict as their value
# print the .keys, .values(), and .items()
# add an entry using the name[] syntax
# overwrite an entry using the same syntax
# MAke a dict of names and job titles, have about 3 entries
jobs = {"Will":"Data Manager",
        "Andy":"Retired",
        "Annie":{"Mondays":"Teacher",
                 "Rest of the week":"Retired"}}
# Make sure one person has multiple jobs using a dict as their value
# print the .keys, .values(), and .items()
print(jobs.keys())
print(jobs.values())
print(jobs.items())

annie_keys = jobs['Annie'].keys()

# add an entry using the name[] syntax
jobs['Naiomi'] = "Policy Writer"
# overwrite an entry using the same syntax
jobs['Will'] = "Python Person"

print(jobs)

# %%
# to separate a string into separate items
# you would use pandas to create a table from the output
email = "william@gmail.com"
name = email.split('@')
print(name)
print(name[0])

name = email.partition("@")
print(name)
